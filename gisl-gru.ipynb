# %% [markdown]
# # Google - Isolated Sign Language Recognition

# %%
# Machine Learning and Data Science Imports (basics)
import tensorflow as tf
import random
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
import numpy as np
import os
from tqdm.notebook import tqdm; tqdm.pandas();
import plotly.express as px
from PIL import Image, ImageEnhance; Image.MAX_IMAGE_PIXELS = 5_000_000_000;
from matplotlib import animation, rc; rc('animation', html='jshtml')
import json
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import plotly.io as pio
pio.templates.default = "simple_white"
import math
import pandas as pd

def seed_it_all(seed=42):
    """ Attempt to be Reproducible """
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)

seed_it_all()

# %%
# import data from specified data directory
def load_json_file(json_path):
    with open(json_path, 'r') as f:
        sign_map = json.load(f)
    return sign_map

class CFG:
    data_dir = "/kaggle/input/asl-signs/"
    sequence_length = 12
    rows_per_frame = 543
    batch_size = 512

ROWS_PER_FRAME = 543
def load_relevant_data_subset(pq_path):
    data_columns = ['x', 'y', 'z']
    data = pd.read_parquet(pq_path, columns=data_columns)
    n_frames = int(len(data) / ROWS_PER_FRAME)
    data = data.values.reshape(n_frames, ROWS_PER_FRAME, len(data_columns))
    return data.astype(np.float32)
    
sign_map = load_json_file(CFG.data_dir + 'sign_to_prediction_index_map.json')
train_data = pd.read_csv(CFG.data_dir + 'train.csv')

s2p_map = {k.lower():v for k,v in load_json_file(CFG.data_dir + "sign_to_prediction_index_map.json").items()}
p2s_map = {v:k for k,v in load_json_file(CFG.data_dir + "sign_to_prediction_index_map.json").items()}
encoder = lambda x: s2p_map.get(x.lower())
decoder = lambda x: p2s_map.get(x)

# inspect data from one parquet file
train_data.head()
# Out:
#                                             path  participant_id  sequence_id  \
# 0  train_landmark_files/26734/1000035562.parquet           26734   1000035562
# 1  train_landmark_files/28656/1000106739.parquet           28656   1000106739
# 2   train_landmark_files/16069/100015657.parquet           16069    100015657
# 3  train_landmark_files/25571/1000210073.parquet           25571   1000210073
# 4  train_landmark_files/62590/1000240708.parquet           62590   1000240708
#
#     sign
# 0   blow
# 1   wait
# 2  cloud
# 3   bird
# 4   owie

# %% [markdown]
# ## Model Pipeline

# %%
from sklearn.preprocessing import normalize
train_x = np.load("/kaggle/input/gislr-feature-data/feature_data.npy").astype(np.float32)
train_y = np.load("/kaggle/input/gislr-feature-data/feature_labels.npy").astype(np.uint8)

N_TOTAL = train_x.shape[0]
VAL_PCT = 0.1
N_VAL   = int(N_TOTAL*VAL_PCT)
N_TRAIN = N_TOTAL-N_VAL

random_idxs = random.sample(range(N_TOTAL), N_TOTAL)
train_idxs, val_idxs = np.array(random_idxs[:N_TRAIN]), np.array(random_idxs[N_TRAIN:])

val_x, val_y = train_x[val_idxs], train_y[val_idxs]
train_x, train_y = train_x[train_idxs], train_y[train_idxs]

# %%
class GatherLayer(tf.keras.layers.Layer):
    def __init__(self, indices, **kwargs):
        super(GatherLayer, self).__init__(**kwargs)
        self.indices = indices
        
    def call(self, inputs):
        return tf.gather(inputs, tf.cast(self.indices, dtype=tf.int32), axis=1)

class ChooseHand(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        
    def call(self, inputs):
        hand_inputs_final = []
        for s in range(inputs.shape[0]):
            left_hand_inputs = inputs[s, 1404:1467]
            right_hand_inputs = inputs[s, 1566:1629]
            hand_inputs = tf.cond(tf.equal(tf.reduce_sum(tf.abs(left_hand_inputs)), 0),
                              lambda: right_hand_inputs,
                              lambda: left_hand_inputs)
            hand_inputs_final.append(hand_inputs)
        stacked_hand_inputs = tf.stack(hand_inputs_final, axis=-1)
        transposed_hand_inputs = tf.transpose(stacked_hand_inputs, perm=[1, 0])
        return transposed_hand_inputs
    
class HandKineticLayer(tf.keras.layers.Layer):
    
    def __init__(self, **kwargs):
        super().__init__()
    
    def call(self, tensor):
        end_ldmrk = [4*3,8*3,12*3,16*3, 19*3]
        for index in range(0, 60, 3):
            start = (index+3) if index in end_ldmrk else (index+6)
        
            dist_list = []
            for x in range(start, 63, 3):
                dx = tensor[:,index] - tensor[:,x]
                dy = tensor[:,index+1] - tensor[:,x+1]
                dist = tf.sqrt(tf.square(dx) + tf.square(dy))
                dist_list.append(dist)
                
            dist_tensor = tf.stack(dist_list, axis=-1)
            tensor = tf.concat([tensor, dist_tensor], axis=-1)
        return tensor
    
    
class FaceKineticLayer(tf.keras.layers.Layer):
    
    def __init__(self, **kwargs):
        super().__init__()
    
    def call(self, tensor):
        for index in range(0, 36, 2):
            start = (index+4)
            
            dist_list = []
            for x in range(start, 40, 2):
                dx = tensor[:,index] - tensor[:,x]
                dy = tensor[:,index+1] - tensor[:,x+1]
                dist = tf.sqrt(tf.square(dx) + tf.square(dy))
                dist_list.append(dist)
            
            dist_tensor = tf.stack(dist_list, axis=-1)
            tensor = tf.concat([tensor, dist_tensor], axis=-1)
        return tensor

    
class AngularLayer(tf.keras.layers.Layer):
    
    def __init__(self, **kwargs):
        super().__init__()
    
    def call(self, tensor):
        for index in range(0, 60, 3):
            start = (index+3) 
            angle_list = []
            for j in range(start, 63, 3):
                vector = tensor[:, j:j+2] - tensor[:, index:index+2] 
                norms = tf.norm(vector, axis=1)
                x_tilt = (tf.clip_by_value(vector[:, 0]/norms, -1.0, 1.0))
                y_tilt = (tf.clip_by_value(vector[:, 1]/norms, -1.0, 1.0))
                angle = tf.stack([x_tilt, y_tilt], axis=1)
                angle_list.append(angle)
            angle_tensor = tf.concat(angle_list, axis=-1)
            tensor = tf.concat([tensor, angle_tensor], axis=-1)
            tensor = tf.cast(tensor, tf.float32)
        return tensor
    
class FaceHandDistance(tf.keras.layers.Layer):
    
    def __init__(self, **kwargs):
        super().__init__()
    
    def call(self, tensor):
        start = 657
        for index in range(0, 42, 2):
            dist_list = []
            for x in range(start, 697, 2):
                dx = tensor[:,index] - tensor[:,x]
                dy = tensor[:,index+1] - tensor[:,x+1]
                dist = tf.sqrt(tf.square(dx) + tf.square(dy))
                dist_list.append(dist)
                
            dist_tensor = tf.stack(dist_list, axis=-1)
            tensor = tf.concat([tensor, dist_tensor], axis=-1)
        return tensor

# %%
output_bias = tf.keras.initializers.Constant(1.0 / 250.0)
def ResidualBlock(inputs, nn, dropout):
    x = tf.keras.layers.Dense(nn)(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("gelu")(x)
    x = tf.keras.layers.Dropout(dropout)(x)
    return x

def GRU(inputs, nn, dropout):
    x = tf.keras.layers.GRU(nn, dropout=0.0, return_sequences=True)(inputs)
    x = tf.keras.layers.GRU(nn, dropout=dropout, return_sequences=False)(inputs)
    return x

class MSD(tf.keras.layers.Layer):
    def __init__(self,units,**kwargs,):
        super().__init__(**kwargs)

        self.lin = tf.keras.layers.Dense(
            units,
            activation=None,
            use_bias=True,
            bias_initializer=output_bias,
        )

        self.dropouts = [tf.keras.layers.Dropout((0.5 - 0.2), seed=135 ),
                tf.keras.layers.Dropout((0.5 - 0.1), seed=690 ),
                tf.keras.layers.Dropout((0.5), seed=275 ),
                tf.keras.layers.Dropout((0.5 + 0.1), seed=348 ),
                tf.keras.layers.Dropout((0.5 + 0.2), seed=861),]

    def call(self, inputs):
        for ii, drop in enumerate(self.dropouts):
            if ii == 0:
                out = self.lin(drop(inputs)) / 5.0
            else:
                out += self.lin(drop(inputs)) / 5.0
        return out

# %%
def build_model():
    inputs = tf.keras.Input(batch_shape=(CFG.batch_size,) + (3258,), dtype=tf.float32)
    hand_inputs = ChooseHand()(inputs) 
    hand_inputs = HandKineticLayer()(hand_inputs)  
    hand_inputs = AngularLayer()(hand_inputs)
    hand_coord = hand_inputs[:, :42]
    hand_features = hand_inputs[:, 63:]
    hand_inputs = tf.keras.layers.Concatenate(axis=1)([hand_coord, hand_features])
    
    lower_lip_indices = [78*3, 191*3, 80*3, 81*3, 82*3, 13*3, 312*3, 311*3, 310*3, 415*3,
            95*3, 88*3, 178*3, 87*3, 14*3, 317*3, 402*3, 318*3, 324*3, 308*3,
            78*3+1, 191*3+1, 80*3+1, 81*3+1, 82*3+1, 13*3+1, 312*3+1, 311*3+1, 310*3+1, 415*3+1,
            95*3+1, 88*3+1, 178*3+1, 87*3+1, 14*3+1, 317*3+1, 402*3+1, 318*3+1, 324*3+1, 308*3+1]
    
    upper_lip_indices = [61*3, 185*3, 40*3, 39*3, 37*3, 0, 267*3, 269*3, 270*3, 409*3,
            291*3, 146*3, 91*3, 181*3, 84*3, 17*3, 314*3, 405*3, 321*3, 375*3,
            61*3+1, 185*3+1, 40*3+1, 39*3+1, 37*3+1, 0+1, 267*3+1, 269*3+1, 270*3+1, 409*3+1,
            291*3+1, 146*3+1, 91*3+1, 181*3+1, 84*3+1, 17*3+1, 314*3+1, 405*3+1, 321*3+1, 375*3+1]
    
    lower_lip_inputs = GatherLayer(lower_lip_indices)(inputs)
    lower_lip_inputs = FaceKineticLayer()(lower_lip_inputs)
    
    upper_lip_inputs = GatherLayer(upper_lip_indices)(inputs)
    upper_lip_inputs = FaceKineticLayer()(upper_lip_inputs)
    
    upper_body_indices = [16*3, 14*3, 12*3, 11*3, 13*3, 15*3,
                          16*3+1, 14*3+1, 12*3+1, 11*3+1, 13*3+1, 15*3+1]
    pose_inputs = GatherLayer(upper_body_indices)(inputs)
    
    all_inputs = tf.keras.layers.Concatenate(axis=1)([hand_inputs, lower_lip_inputs, upper_lip_inputs, pose_inputs])
#     all_inputs = FaceHandDistance()(all_inputs)
    
    all_conv = tf.reshape(all_inputs, (-1, 1, all_inputs.shape[1]))
    
    vector = GRU(all_conv, 1024//2, 0.5)     
    vector = ResidualBlock(vector, 1024//1, 0.25)     
    vector = ResidualBlock(vector, 1024//1, 0.0)
    vector = MSD(1024//4)(vector)
    
    vector = tf.keras.layers.Flatten()(vector)
    output = tf.keras.layers.Dense(250, activation="softmax")(vector)
    model = tf.keras.Model(inputs=inputs, outputs=output)
    model.compile(tf.keras.optimizers.Adam(0.000333), "sparse_categorical_crossentropy", 
                  metrics =["sparse_top_k_categorical_accuracy", "acc"])
    return model

# %% [markdown]
# ## Model 1

# %%
import keras.backend as K

K.clear_session()
model1 = build_model()
model1.summary()
# tf.keras.utils.plot_model(model1)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(512, 3258)]        0           []
#
#  choose_hand (ChooseHand)       (512, 63)            0           ['input_1[0][0]']
#
#  hand_kinetic_layer (HandKineti  (512, 258)          0           ['choose_hand[0][0]']
#  cLayer)
#
#  angular_layer (AngularLayer)   (512, 678)           0           ['hand_kinetic_layer[0][0]']
#
#  tf.__operators__.getitem (Slic  (512, 42)           0           ['angular_layer[0][0]']
#  ingOpLambda)
#
#  tf.__operators__.getitem_1 (Sl  (512, 615)          0           ['angular_layer[0][0]']
#  icingOpLambda)
#
#  gather_layer (GatherLayer)     (512, 40)            0           ['input_1[0][0]']
#
#  gather_layer_1 (GatherLayer)   (512, 40)            0           ['input_1[0][0]']
#
#  concatenate (Concatenate)      (512, 657)           0           ['tf.__operators__.getitem[0][0]'
#                                                                  , 'tf.__operators__.getitem_1[0][
#                                                                  0]']
#
#  face_kinetic_layer (FaceKineti  (512, 211)          0           ['gather_layer[0][0]']
#  cLayer)
#
#  face_kinetic_layer_1 (FaceKine  (512, 211)          0           ['gather_layer_1[0][0]']
#  ticLayer)
#
#  gather_layer_2 (GatherLayer)   (512, 12)            0           ['input_1[0][0]']
#
#  concatenate_1 (Concatenate)    (512, 1091)          0           ['concatenate[0][0]',
#                                                                   'face_kinetic_layer[0][0]',
#                                                                   'face_kinetic_layer_1[0][0]',
#                                                                   'gather_layer_2[0][0]']
#
#  tf.reshape (TFOpLambda)        (512, 1, 1091)       0           ['concatenate_1[0][0]']
#
#  gru_1 (GRU)                    (512, 512)           2465280     ['tf.reshape[0][0]']
#
#  dense (Dense)                  (512, 1024)          525312      ['gru_1[0][0]']
#
#  batch_normalization (BatchNorm  (512, 1024)         4096        ['dense[0][0]']
#  alization)
#
#  activation (Activation)        (512, 1024)          0           ['batch_normalization[0][0]']
#
#  dropout (Dropout)              (512, 1024)          0           ['activation[0][0]']
#
#  dense_1 (Dense)                (512, 1024)          1049600     ['dropout[0][0]']
#
#  batch_normalization_1 (BatchNo  (512, 1024)         4096        ['dense_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (512, 1024)          0           ['batch_normalization_1[0][0]']
#
#  dropout_1 (Dropout)            (512, 1024)          0           ['activation_1[0][0]']
#
#  msd (MSD)                      (512, 256)           262400      ['dropout_1[0][0]']
#
#  flatten (Flatten)              (512, 256)           0           ['msd[0][0]']
#
#  dense_3 (Dense)                (512, 250)           64250       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 4,375,034
# Trainable params: 4,370,938
# Non-trainable params: 4,096
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train Model

# %%
file_name = "model1"
callbacks = [
        tf.keras.callbacks.ModelCheckpoint(
            file_name, 
            save_best_only=True, 
            restore_best_weights=True, 
            monitor="val_accuracy",
            mode="max"
        ),
        tf.keras.callbacks.EarlyStopping(
            monitor="val_accuracy",
            mode="max",
            patience=5
        ),
        tf.keras.callbacks.ReduceLROnPlateau(patience=2, factor=0.8, verbose=1)
    ]

train_dataset = tf.data.Dataset.from_tensor_slices((train_x, train_y))
train_dataset = train_dataset.batch(batch_size=CFG.batch_size, drop_remainder=True)
val_dataset = tf.data.Dataset.from_tensor_slices((val_x, val_y))
val_dataset = val_dataset.batch(batch_size=CFG.batch_size, drop_remainder=True)

model1.fit(train_dataset, epochs=100, validation_data=val_dataset, batch_size=CFG.batch_size, callbacks=callbacks)
# Out:
# Epoch 1/100
# 166/166 [==============================] - 113s 319ms/step - loss: 4.4715 - sparse_top_k_categorical_accuracy: 0.2607 - acc: 0.0913 - val_loss: 3.7939 - val_sparse_top_k_categorical_accuracy: 0.4796 - val_acc: 0.2123 - lr: 3.3300e-04
# Epoch 2/100
# 166/166 [==============================] - 21s 128ms/step - loss: 3.5102 - sparse_top_k_categorical_accuracy: 0.4796 - acc: 0.1996 - val_loss: 3.0422 - val_sparse_top_k_categorical_accuracy: 0.5847 - val_acc: 0.2882 - lr: 3.3300e-04
# Epoch 3/100
# 166/166 [==============================] - 21s 129ms/step - loss: 3.2087 - sparse_top_k_categorical_accuracy: 0.5525 - acc: 0.2483 - val_loss: 2.8039 - val_sparse_top_k_categorical_accuracy: 0.6360 - val_acc: 0.3238 - lr: 3.3300e-04
# Epoch 4/100
# 166/166 [==============================] - 21s 127ms/step - loss: 3.0291 - sparse_top_k_categorical_accuracy: 0.5902 - acc: 0.2811 - val_loss: 2.6573 - val_sparse_top_k_categorical_accuracy: 0.6707 - val_acc: 0.3513 - lr: 3.3300e-04
# Epoch 5/100
# 166/166 [==============================] - 21s 128ms/step - loss: 2.8995 - sparse_top_k_categorical_accuracy: 0.6193 - acc: 0.3029 - val_loss: 2.5441 - val_sparse_top_k_categorical_accuracy: 0.6931 - val_acc: 0.3804 - lr: 3.3300e-04
# Epoch 6/100
# 166/166 [==============================] - 21s 128ms/step - loss: 2.8163 - sparse_top_k_categorical_accuracy: 0.6354 - acc: 0.3202 - val_loss: 2.4704 - val_sparse_top_k_categorical_accuracy: 0.7076 - val_acc: 0.3933 - lr: 3.3300e-04
# Epoch 7/100
# 166/166 [==============================] - 21s 125ms/step - loss: 2.7315 - sparse_top_k_categorical_accuracy: 0.6547 - acc: 0.3344 - val_loss: 2.3929 - val_sparse_top_k_categorical_accuracy: 0.7208 - val_acc: 0.4112 - lr: 3.3300e-04
# Epoch 8/100
# 166/166 [==============================] - 21s 128ms/step - loss: 2.6688 - sparse_top_k_categorical_accuracy: 0.6670 - acc: 0.3462 - val_loss: 2.3396 - val_sparse_top_k_categorical_accuracy: 0.7284 - val_acc: 0.4235 - lr: 3.3300e-04
# Epoch 9/100
# 166/166 [==============================] - 21s 127ms/step - loss: 2.6129 - sparse_top_k_categorical_accuracy: 0.6767 - acc: 0.3590 - val_loss: 2.2867 - val_sparse_top_k_categorical_accuracy: 0.7388 - val_acc: 0.4337 - lr: 3.3300e-04
# Epoch 10/100
# 166/166 [==============================] - 21s 124ms/step - loss: 2.5615 - sparse_top_k_categorical_accuracy: 0.6879 - acc: 0.3688 - val_loss: 2.2507 - val_sparse_top_k_categorical_accuracy: 0.7449 - val_acc: 0.4428 - lr: 3.3300e-04
# Epoch 11/100
# 166/166 [==============================] - 21s 128ms/step - loss: 2.5180 - sparse_top_k_categorical_accuracy: 0.6963 - acc: 0.3767 - val_loss: 2.2050 - val_sparse_top_k_categorical_accuracy: 0.7525 - val_acc: 0.4592 - lr: 3.3300e-04
# Epoch 12/100
# 166/166 [==============================] - 21s 125ms/step - loss: 2.4762 - sparse_top_k_categorical_accuracy: 0.7036 - acc: 0.3856 - val_loss: 2.1737 - val_sparse_top_k_categorical_accuracy: 0.7587 - val_acc: 0.4625 - lr: 3.3300e-04
# Epoch 13/100
# 166/166 [==============================] - 20s 123ms/step - loss: 2.4387 - sparse_top_k_categorical_accuracy: 0.7106 - acc: 0.3940 - val_loss: 2.1320 - val_sparse_top_k_categorical_accuracy: 0.7655 - val_acc: 0.4715 - lr: 3.3300e-04
# Epoch 14/100
# 166/166 [==============================] - 21s 124ms/step - loss: 2.3982 - sparse_top_k_categorical_accuracy: 0.7183 - acc: 0.3983 - val_loss: 2.1116 - val_sparse_top_k_categorical_accuracy: 0.7665 - val_acc: 0.4761 - lr: 3.3300e-04
# Epoch 15/100
# 166/166 [==============================] - 21s 124ms/step - loss: 2.3696 - sparse_top_k_categorical_accuracy: 0.7216 - acc: 0.4076 - val_loss: 2.0779 - val_sparse_top_k_categorical_accuracy: 0.7737 - val_acc: 0.4868 - lr: 3.3300e-04
# Epoch 16/100
# 166/166 [==============================] - 21s 124ms/step - loss: 2.3388 - sparse_top_k_categorical_accuracy: 0.7291 - acc: 0.4111 - val_loss: 2.0561 - val_sparse_top_k_categorical_accuracy: 0.7768 - val_acc: 0.4895 - lr: 3.3300e-04
# Epoch 17/100
# 166/166 [==============================] - 21s 125ms/step - loss: 2.3014 - sparse_top_k_categorical_accuracy: 0.7334 - acc: 0.4167 - val_loss: 2.0343 - val_sparse_top_k_categorical_accuracy: 0.7816 - val_acc: 0.4982 - lr: 3.3300e-04
# Epoch 18/100
# 166/166 [==============================] - 20s 120ms/step - loss: 2.2727 - sparse_top_k_categorical_accuracy: 0.7389 - acc: 0.4239 - val_loss: 2.0017 - val_sparse_top_k_categorical_accuracy: 0.7870 - val_acc: 0.5040 - lr: 3.3300e-04
# Epoch 19/100
# 166/166 [==============================] - 21s 124ms/step - loss: 2.2499 - sparse_top_k_categorical_accuracy: 0.7437 - acc: 0.4306 - val_loss: 1.9917 - val_sparse_top_k_categorical_accuracy: 0.7883 - val_acc: 0.5109 - lr: 3.3300e-04
# Epoch 20/100
# 166/166 [==============================] - 21s 124ms/step - loss: 2.2222 - sparse_top_k_categorical_accuracy: 0.7486 - acc: 0.4362 - val_loss: 1.9803 - val_sparse_top_k_categorical_accuracy: 0.7878 - val_acc: 0.5148 - lr: 3.3300e-04
# Epoch 21/100
# 166/166 [==============================] - 20s 122ms/step - loss: 2.2005 - sparse_top_k_categorical_accuracy: 0.7513 - acc: 0.4387 - val_loss: 1.9701 - val_sparse_top_k_categorical_accuracy: 0.7882 - val_acc: 0.5155 - lr: 3.3300e-04
# Epoch 22/100
# 166/166 [==============================] - 21s 126ms/step - loss: 2.1756 - sparse_top_k_categorical_accuracy: 0.7557 - acc: 0.4455 - val_loss: 1.9342 - val_sparse_top_k_categorical_accuracy: 0.7946 - val_acc: 0.5221 - lr: 3.3300e-04
# Epoch 23/100
# 166/166 [==============================] - 21s 125ms/step - loss: 2.1511 - sparse_top_k_categorical_accuracy: 0.7610 - acc: 0.4488 - val_loss: 1.9335 - val_sparse_top_k_categorical_accuracy: 0.7943 - val_acc: 0.5232 - lr: 3.3300e-04
# Epoch 24/100
# 166/166 [==============================] - 20s 123ms/step - loss: 2.1346 - sparse_top_k_categorical_accuracy: 0.7633 - acc: 0.4495 - val_loss: 1.9102 - val_sparse_top_k_categorical_accuracy: 0.7958 - val_acc: 0.5284 - lr: 3.3300e-04
# Epoch 25/100
# 166/166 [==============================] - 21s 125ms/step - loss: 2.1042 - sparse_top_k_categorical_accuracy: 0.7675 - acc: 0.4577 - val_loss: 1.9059 - val_sparse_top_k_categorical_accuracy: 0.7979 - val_acc: 0.5331 - lr: 3.3300e-04
# Epoch 26/100
# 166/166 [==============================] - 21s 127ms/step - loss: 2.0877 - sparse_top_k_categorical_accuracy: 0.7710 - acc: 0.4623 - val_loss: 1.8935 - val_sparse_top_k_categorical_accuracy: 0.8003 - val_acc: 0.5332 - lr: 3.3300e-04
# Epoch 27/100
# 166/166 [==============================] - 21s 124ms/step - loss: 2.0680 - sparse_top_k_categorical_accuracy: 0.7733 - acc: 0.4658 - val_loss: 1.8690 - val_sparse_top_k_categorical_accuracy: 0.8024 - val_acc: 0.5394 - lr: 3.3300e-04
# Epoch 28/100
# 166/166 [==============================] - 21s 125ms/step - loss: 2.0453 - sparse_top_k_categorical_accuracy: 0.7782 - acc: 0.4695 - val_loss: 1.8730 - val_sparse_top_k_categorical_accuracy: 0.8021 - val_acc: 0.5423 - lr: 3.3300e-04
# Epoch 29/100
# 166/166 [==============================] - 21s 124ms/step - loss: 2.0265 - sparse_top_k_categorical_accuracy: 0.7821 - acc: 0.4742 - val_loss: 1.8638 - val_sparse_top_k_categorical_accuracy: 0.8011 - val_acc: 0.5433 - lr: 3.3300e-04
# Epoch 30/100
# 166/166 [==============================] - 20s 123ms/step - loss: 2.0060 - sparse_top_k_categorical_accuracy: 0.7842 - acc: 0.4761 - val_loss: 1.8416 - val_sparse_top_k_categorical_accuracy: 0.8061 - val_acc: 0.5505 - lr: 3.3300e-04
# Epoch 31/100
# 166/166 [==============================] - 21s 125ms/step - loss: 1.9902 - sparse_top_k_categorical_accuracy: 0.7870 - acc: 0.4819 - val_loss: 1.8396 - val_sparse_top_k_categorical_accuracy: 0.8062 - val_acc: 0.5471 - lr: 3.3300e-04
# Epoch 32/100
# 166/166 [==============================] - 20s 122ms/step - loss: 1.9692 - sparse_top_k_categorical_accuracy: 0.7893 - acc: 0.4838 - val_loss: 1.8389 - val_sparse_top_k_categorical_accuracy: 0.8044 - val_acc: 0.5481 - lr: 3.3300e-04
# Epoch 33/100
# 166/166 [==============================] - 21s 124ms/step - loss: 1.9551 - sparse_top_k_categorical_accuracy: 0.7923 - acc: 0.4886 - val_loss: 1.8265 - val_sparse_top_k_categorical_accuracy: 0.8072 - val_acc: 0.5515 - lr: 3.3300e-04
# Epoch 34/100
# 166/166 [==============================] - 20s 123ms/step - loss: 1.9306 - sparse_top_k_categorical_accuracy: 0.7958 - acc: 0.4928 - val_loss: 1.8153 - val_sparse_top_k_categorical_accuracy: 0.8095 - val_acc: 0.5561 - lr: 3.3300e-04
# Epoch 35/100
# 166/166 [==============================] - 20s 121ms/step - loss: 1.9185 - sparse_top_k_categorical_accuracy: 0.7971 - acc: 0.4968 - val_loss: 1.8195 - val_sparse_top_k_categorical_accuracy: 0.8079 - val_acc: 0.5521 - lr: 3.3300e-04
# Epoch 36/100
# 166/166 [==============================] - 21s 125ms/step - loss: 1.9076 - sparse_top_k_categorical_accuracy: 0.7996 - acc: 0.4966 - val_loss: 1.8044 - val_sparse_top_k_categorical_accuracy: 0.8108 - val_acc: 0.5579 - lr: 3.3300e-04
# Epoch 37/100
# 166/166 [==============================] - 21s 127ms/step - loss: 1.8918 - sparse_top_k_categorical_accuracy: 0.8034 - acc: 0.5025 - val_loss: 1.7990 - val_sparse_top_k_categorical_accuracy: 0.8082 - val_acc: 0.5618 - lr: 3.3300e-04
# Epoch 38/100
# 166/166 [==============================] - 21s 129ms/step - loss: 1.8684 - sparse_top_k_categorical_accuracy: 0.8072 - acc: 0.5058 - val_loss: 1.7933 - val_sparse_top_k_categorical_accuracy: 0.8117 - val_acc: 0.5638 - lr: 3.3300e-04
# Epoch 39/100
# 166/166 [==============================] - 21s 129ms/step - loss: 1.8495 - sparse_top_k_categorical_accuracy: 0.8084 - acc: 0.5094 - val_loss: 1.7839 - val_sparse_top_k_categorical_accuracy: 0.8132 - val_acc: 0.5679 - lr: 3.3300e-04
# Epoch 40/100
# 166/166 [==============================] - 21s 124ms/step - loss: 1.8444 - sparse_top_k_categorical_accuracy: 0.8105 - acc: 0.5097 - val_loss: 1.7813 - val_sparse_top_k_categorical_accuracy: 0.8125 - val_acc: 0.5662 - lr: 3.3300e-04
# Epoch 41/100
# 166/166 [==============================] - 20s 121ms/step - loss: 1.8251 - sparse_top_k_categorical_accuracy: 0.8131 - acc: 0.5122 - val_loss: 1.7786 - val_sparse_top_k_categorical_accuracy: 0.8141 - val_acc: 0.5672 - lr: 3.3300e-04
# Epoch 42/100
# 166/166 [==============================] - 21s 126ms/step - loss: 1.8163 - sparse_top_k_categorical_accuracy: 0.8146 - acc: 0.5158 - val_loss: 1.7740 - val_sparse_top_k_categorical_accuracy: 0.8127 - val_acc: 0.5720 - lr: 3.3300e-04
# Epoch 43/100
# 166/166 [==============================] - 20s 120ms/step - loss: 1.7944 - sparse_top_k_categorical_accuracy: 0.8179 - acc: 0.5202 - val_loss: 1.7664 - val_sparse_top_k_categorical_accuracy: 0.8130 - val_acc: 0.5714 - lr: 3.3300e-04
# Epoch 44/100
# 166/166 [==============================] - 21s 124ms/step - loss: 1.7822 - sparse_top_k_categorical_accuracy: 0.8192 - acc: 0.5226 - val_loss: 1.7656 - val_sparse_top_k_categorical_accuracy: 0.8155 - val_acc: 0.5723 - lr: 3.3300e-04
# Epoch 45/100
# 166/166 [==============================] - 20s 124ms/step - loss: 1.7644 - sparse_top_k_categorical_accuracy: 0.8223 - acc: 0.5283 - val_loss: 1.7571 - val_sparse_top_k_categorical_accuracy: 0.8148 - val_acc: 0.5700 - lr: 3.3300e-04
# Epoch 46/100
# 166/166 [==============================] - 20s 121ms/step - loss: 1.7553 - sparse_top_k_categorical_accuracy: 0.8233 - acc: 0.5279 - val_loss: 1.7548 - val_sparse_top_k_categorical_accuracy: 0.8176 - val_acc: 0.5765 - lr: 3.3300e-04
# Epoch 47/100
# 166/166 [==============================] - 21s 125ms/step - loss: 1.7415 - sparse_top_k_categorical_accuracy: 0.8263 - acc: 0.5306 - val_loss: 1.7453 - val_sparse_top_k_categorical_accuracy: 0.8172 - val_acc: 0.5803 - lr: 3.3300e-04
# Epoch 48/100
# 166/166 [==============================] - 21s 127ms/step - loss: 1.7261 - sparse_top_k_categorical_accuracy: 0.8277 - acc: 0.5333 - val_loss: 1.7642 - val_sparse_top_k_categorical_accuracy: 0.8142 - val_acc: 0.5771 - lr: 3.3300e-04
# Epoch 49/100
# 166/166 [==============================] - ETA: 0s - loss: 1.7154 - sparse_top_k_categorical_accuracy: 0.8297 - acc: 0.5359
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.000266400002874434.
# 166/166 [==============================] - 20s 120ms/step - loss: 1.7154 - sparse_top_k_categorical_accuracy: 0.8297 - acc: 0.5359 - val_loss: 1.7481 - val_sparse_top_k_categorical_accuracy: 0.8174 - val_acc: 0.5782 - lr: 3.3300e-04
# Epoch 50/100
# 166/166 [==============================] - 20s 123ms/step - loss: 1.6794 - sparse_top_k_categorical_accuracy: 0.8348 - acc: 0.5457 - val_loss: 1.7272 - val_sparse_top_k_categorical_accuracy: 0.8158 - val_acc: 0.5838 - lr: 2.6640e-04
# Epoch 51/100
# 166/166 [==============================] - 21s 125ms/step - loss: 1.6658 - sparse_top_k_categorical_accuracy: 0.8387 - acc: 0.5487 - val_loss: 1.7356 - val_sparse_top_k_categorical_accuracy: 0.8167 - val_acc: 0.5809 - lr: 2.6640e-04
# Epoch 52/100
# 166/166 [==============================] - ETA: 0s - loss: 1.6472 - sparse_top_k_categorical_accuracy: 0.8417 - acc: 0.5508
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.00021311999298632145.
# 166/166 [==============================] - 21s 125ms/step - loss: 1.6472 - sparse_top_k_categorical_accuracy: 0.8417 - acc: 0.5508 - val_loss: 1.7317 - val_sparse_top_k_categorical_accuracy: 0.8178 - val_acc: 0.5824 - lr: 2.6640e-04
# Epoch 53/100
# 166/166 [==============================] - 20s 124ms/step - loss: 1.6284 - sparse_top_k_categorical_accuracy: 0.8433 - acc: 0.5561 - val_loss: 1.7205 - val_sparse_top_k_categorical_accuracy: 0.8197 - val_acc: 0.5880 - lr: 2.1312e-04
# Epoch 54/100
# 166/166 [==============================] - 20s 121ms/step - loss: 1.6059 - sparse_top_k_categorical_accuracy: 0.8467 - acc: 0.5605 - val_loss: 1.7189 - val_sparse_top_k_categorical_accuracy: 0.8187 - val_acc: 0.5882 - lr: 2.1312e-04
# Epoch 55/100
# 166/166 [==============================] - 21s 127ms/step - loss: 1.6002 - sparse_top_k_categorical_accuracy: 0.8478 - acc: 0.5626 - val_loss: 1.7169 - val_sparse_top_k_categorical_accuracy: 0.8194 - val_acc: 0.5907 - lr: 2.1312e-04
# Epoch 56/100
# 166/166 [==============================] - 20s 122ms/step - loss: 1.5896 - sparse_top_k_categorical_accuracy: 0.8494 - acc: 0.5634 - val_loss: 1.7139 - val_sparse_top_k_categorical_accuracy: 0.8205 - val_acc: 0.5914 - lr: 2.1312e-04
# Epoch 57/100
# 166/166 [==============================] - 21s 125ms/step - loss: 1.5761 - sparse_top_k_categorical_accuracy: 0.8511 - acc: 0.5681 - val_loss: 1.7104 - val_sparse_top_k_categorical_accuracy: 0.8212 - val_acc: 0.5938 - lr: 2.1312e-04
# Epoch 58/100
# 166/166 [==============================] - 21s 124ms/step - loss: 1.5680 - sparse_top_k_categorical_accuracy: 0.8526 - acc: 0.5693 - val_loss: 1.7101 - val_sparse_top_k_categorical_accuracy: 0.8201 - val_acc: 0.5930 - lr: 2.1312e-04
# Epoch 59/100
# 166/166 [==============================] - 21s 124ms/step - loss: 1.5516 - sparse_top_k_categorical_accuracy: 0.8561 - acc: 0.5714 - val_loss: 1.7139 - val_sparse_top_k_categorical_accuracy: 0.8198 - val_acc: 0.5926 - lr: 2.1312e-04
# Epoch 60/100
# 166/166 [==============================] - ETA: 0s - loss: 1.5499 - sparse_top_k_categorical_accuracy: 0.8549 - acc: 0.5741
# Epoch 60: ReduceLROnPlateau reducing learning rate to 0.0001704959897324443.
# 166/166 [==============================] - 21s 125ms/step - loss: 1.5499 - sparse_top_k_categorical_accuracy: 0.8549 - acc: 0.5741 - val_loss: 1.7193 - val_sparse_top_k_categorical_accuracy: 0.8189 - val_acc: 0.5921 - lr: 2.1312e-04
# Epoch 61/100
# 166/166 [==============================] - 21s 124ms/step - loss: 1.5284 - sparse_top_k_categorical_accuracy: 0.8583 - acc: 0.5779 - val_loss: 1.7066 - val_sparse_top_k_categorical_accuracy: 0.8219 - val_acc: 0.5932 - lr: 1.7050e-04
# Epoch 62/100
# 166/166 [==============================] - 20s 121ms/step - loss: 1.5167 - sparse_top_k_categorical_accuracy: 0.8610 - acc: 0.5800 - val_loss: 1.7051 - val_sparse_top_k_categorical_accuracy: 0.8214 - val_acc: 0.5978 - lr: 1.7050e-04
# Epoch 63/100
# 166/166 [==============================] - 21s 124ms/step - loss: 1.5074 - sparse_top_k_categorical_accuracy: 0.8621 - acc: 0.5843 - val_loss: 1.7008 - val_sparse_top_k_categorical_accuracy: 0.8248 - val_acc: 0.5960 - lr: 1.7050e-04
# Epoch 64/100
# 166/166 [==============================] - 21s 129ms/step - loss: 1.4983 - sparse_top_k_categorical_accuracy: 0.8633 - acc: 0.5826 - val_loss: 1.7000 - val_sparse_top_k_categorical_accuracy: 0.8225 - val_acc: 0.6010 - lr: 1.7050e-04
# Epoch 65/100
# 166/166 [==============================] - 21s 126ms/step - loss: 1.4986 - sparse_top_k_categorical_accuracy: 0.8629 - acc: 0.5847 - val_loss: 1.6983 - val_sparse_top_k_categorical_accuracy: 0.8240 - val_acc: 0.6011 - lr: 1.7050e-04
# Epoch 66/100
# 166/166 [==============================] - 21s 125ms/step - loss: 1.4778 - sparse_top_k_categorical_accuracy: 0.8664 - acc: 0.5897 - val_loss: 1.7012 - val_sparse_top_k_categorical_accuracy: 0.8218 - val_acc: 0.6006 - lr: 1.7050e-04
# Epoch 67/100
# 166/166 [==============================] - ETA: 0s - loss: 1.4792 - sparse_top_k_categorical_accuracy: 0.8659 - acc: 0.5893
# Epoch 67: ReduceLROnPlateau reducing learning rate to 0.000136396789457649.
# 166/166 [==============================] - 20s 122ms/step - loss: 1.4792 - sparse_top_k_categorical_accuracy: 0.8659 - acc: 0.5893 - val_loss: 1.7066 - val_sparse_top_k_categorical_accuracy: 0.8222 - val_acc: 0.5973 - lr: 1.7050e-04
# Epoch 68/100
# 166/166 [==============================] - 21s 127ms/step - loss: 1.4590 - sparse_top_k_categorical_accuracy: 0.8685 - acc: 0.5943 - val_loss: 1.6925 - val_sparse_top_k_categorical_accuracy: 0.8256 - val_acc: 0.6011 - lr: 1.3640e-04
# Epoch 69/100
# 166/166 [==============================] - 23s 137ms/step - loss: 1.4478 - sparse_top_k_categorical_accuracy: 0.8706 - acc: 0.5959 - val_loss: 1.6972 - val_sparse_top_k_categorical_accuracy: 0.8248 - val_acc: 0.6012 - lr: 1.3640e-04
# Epoch 70/100
# 166/166 [==============================] - ETA: 0s - loss: 1.4451 - sparse_top_k_categorical_accuracy: 0.8719 - acc: 0.5954
# Epoch 70: ReduceLROnPlateau reducing learning rate to 0.0001091174315661192.
# 166/166 [==============================] - 21s 129ms/step - loss: 1.4451 - sparse_top_k_categorical_accuracy: 0.8719 - acc: 0.5954 - val_loss: 1.6979 - val_sparse_top_k_categorical_accuracy: 0.8224 - val_acc: 0.6017 - lr: 1.3640e-04
# Epoch 71/100
# 166/166 [==============================] - 22s 132ms/step - loss: 1.4279 - sparse_top_k_categorical_accuracy: 0.8739 - acc: 0.6010 - val_loss: 1.6904 - val_sparse_top_k_categorical_accuracy: 0.8264 - val_acc: 0.6029 - lr: 1.0912e-04
# Epoch 72/100
# 166/166 [==============================] - 21s 129ms/step - loss: 1.4193 - sparse_top_k_categorical_accuracy: 0.8744 - acc: 0.6028 - val_loss: 1.6974 - val_sparse_top_k_categorical_accuracy: 0.8241 - val_acc: 0.6020 - lr: 1.0912e-04
# Epoch 73/100
# 166/166 [==============================] - ETA: 0s - loss: 1.4193 - sparse_top_k_categorical_accuracy: 0.8745 - acc: 0.6029
# Epoch 73: ReduceLROnPlateau reducing learning rate to 8.72939475812018e-05.
# 166/166 [==============================] - 21s 126ms/step - loss: 1.4193 - sparse_top_k_categorical_accuracy: 0.8745 - acc: 0.6029 - val_loss: 1.6943 - val_sparse_top_k_categorical_accuracy: 0.8260 - val_acc: 0.6033 - lr: 1.0912e-04
# Epoch 74/100
# 166/166 [==============================] - 20s 122ms/step - loss: 1.4047 - sparse_top_k_categorical_accuracy: 0.8765 - acc: 0.6060 - val_loss: 1.6844 - val_sparse_top_k_categorical_accuracy: 0.8265 - val_acc: 0.6061 - lr: 8.7294e-05
# Epoch 75/100
# 166/166 [==============================] - 21s 128ms/step - loss: 1.3925 - sparse_top_k_categorical_accuracy: 0.8782 - acc: 0.6096 - val_loss: 1.6874 - val_sparse_top_k_categorical_accuracy: 0.8261 - val_acc: 0.6051 - lr: 8.7294e-05
# Epoch 76/100
# 166/166 [==============================] - ETA: 0s - loss: 1.3908 - sparse_top_k_categorical_accuracy: 0.8797 - acc: 0.6096
# Epoch 76: ReduceLROnPlateau reducing learning rate to 6.983515922911466e-05.
# 166/166 [==============================] - 21s 124ms/step - loss: 1.3908 - sparse_top_k_categorical_accuracy: 0.8797 - acc: 0.6096 - val_loss: 1.6856 - val_sparse_top_k_categorical_accuracy: 0.8269 - val_acc: 0.6069 - lr: 8.7294e-05
# Epoch 77/100
# 166/166 [==============================] - 22s 130ms/step - loss: 1.3781 - sparse_top_k_categorical_accuracy: 0.8812 - acc: 0.6126 - val_loss: 1.6861 - val_sparse_top_k_categorical_accuracy: 0.8252 - val_acc: 0.6069 - lr: 6.9835e-05
# Epoch 78/100
# 166/166 [==============================] - ETA: 0s - loss: 1.3828 - sparse_top_k_categorical_accuracy: 0.8799 - acc: 0.6091
# Epoch 78: ReduceLROnPlateau reducing learning rate to 5.586812621913851e-05.
# 166/166 [==============================] - 21s 124ms/step - loss: 1.3828 - sparse_top_k_categorical_accuracy: 0.8799 - acc: 0.6091 - val_loss: 1.6894 - val_sparse_top_k_categorical_accuracy: 0.8249 - val_acc: 0.6038 - lr: 6.9835e-05
# Epoch 79/100
# 166/166 [==============================] - 20s 121ms/step - loss: 1.3658 - sparse_top_k_categorical_accuracy: 0.8824 - acc: 0.6142 - val_loss: 1.6847 - val_sparse_top_k_categorical_accuracy: 0.8253 - val_acc: 0.6062 - lr: 5.5868e-05
# Epoch 80/100
# 166/166 [==============================] - 21s 125ms/step - loss: 1.3643 - sparse_top_k_categorical_accuracy: 0.8824 - acc: 0.6157 - val_loss: 1.6841 - val_sparse_top_k_categorical_accuracy: 0.8280 - val_acc: 0.6085 - lr: 5.5868e-05
# Epoch 81/100
# 166/166 [==============================] - 20s 122ms/step - loss: 1.3586 - sparse_top_k_categorical_accuracy: 0.8832 - acc: 0.6184 - val_loss: 1.6869 - val_sparse_top_k_categorical_accuracy: 0.8258 - val_acc: 0.6086 - lr: 5.5868e-05
# Epoch 82/100
# 166/166 [==============================] - 21s 125ms/step - loss: 1.3568 - sparse_top_k_categorical_accuracy: 0.8829 - acc: 0.6170 - val_loss: 1.6833 - val_sparse_top_k_categorical_accuracy: 0.8265 - val_acc: 0.6090 - lr: 5.5868e-05
# Epoch 83/100
# 166/166 [==============================] - 20s 121ms/step - loss: 1.3517 - sparse_top_k_categorical_accuracy: 0.8850 - acc: 0.6194 - val_loss: 1.6834 - val_sparse_top_k_categorical_accuracy: 0.8275 - val_acc: 0.6071 - lr: 5.5868e-05
# Epoch 84/100
# 166/166 [==============================] - ETA: 0s - loss: 1.3481 - sparse_top_k_categorical_accuracy: 0.8855 - acc: 0.6208
# Epoch 84: ReduceLROnPlateau reducing learning rate to 4.4694502139464025e-05.
# 166/166 [==============================] - 21s 125ms/step - loss: 1.3481 - sparse_top_k_categorical_accuracy: 0.8855 - acc: 0.6208 - val_loss: 1.6848 - val_sparse_top_k_categorical_accuracy: 0.8277 - val_acc: 0.6069 - lr: 5.5868e-05
# Epoch 85/100
# 166/166 [==============================] - 21s 125ms/step - loss: 1.3427 - sparse_top_k_categorical_accuracy: 0.8851 - acc: 0.6199 - val_loss: 1.6818 - val_sparse_top_k_categorical_accuracy: 0.8276 - val_acc: 0.6076 - lr: 4.4695e-05
# Epoch 86/100
# 166/166 [==============================] - 21s 124ms/step - loss: 1.3386 - sparse_top_k_categorical_accuracy: 0.8863 - acc: 0.6206 - val_loss: 1.6848 - val_sparse_top_k_categorical_accuracy: 0.8278 - val_acc: 0.6070 - lr: 4.4695e-05
# Epoch 87/100
# 166/166 [==============================] - 20s 123ms/step - loss: 1.3334 - sparse_top_k_categorical_accuracy: 0.8867 - acc: 0.6242 - val_loss: 1.6812 - val_sparse_top_k_categorical_accuracy: 0.8292 - val_acc: 0.6074 - lr: 4.4695e-05
# Epoch 88/100
# 166/166 [==============================] - 20s 121ms/step - loss: 1.3409 - sparse_top_k_categorical_accuracy: 0.8853 - acc: 0.6211 - val_loss: 1.6799 - val_sparse_top_k_categorical_accuracy: 0.8287 - val_acc: 0.6096 - lr: 4.4695e-05
# Epoch 89/100
# 166/166 [==============================] - 21s 126ms/step - loss: 1.3326 - sparse_top_k_categorical_accuracy: 0.8874 - acc: 0.6245 - val_loss: 1.6852 - val_sparse_top_k_categorical_accuracy: 0.8289 - val_acc: 0.6068 - lr: 4.4695e-05
# Epoch 90/100
# 166/166 [==============================] - ETA: 0s - loss: 1.3353 - sparse_top_k_categorical_accuracy: 0.8866 - acc: 0.6239
# Epoch 90: ReduceLROnPlateau reducing learning rate to 3.575560112949461e-05.
# 166/166 [==============================] - 20s 122ms/step - loss: 1.3353 - sparse_top_k_categorical_accuracy: 0.8866 - acc: 0.6239 - val_loss: 1.6844 - val_sparse_top_k_categorical_accuracy: 0.8276 - val_acc: 0.6072 - lr: 4.4695e-05
# Epoch 91/100
# 166/166 [==============================] - 21s 127ms/step - loss: 1.3242 - sparse_top_k_categorical_accuracy: 0.8879 - acc: 0.6264 - val_loss: 1.6837 - val_sparse_top_k_categorical_accuracy: 0.8274 - val_acc: 0.6096 - lr: 3.5756e-05
# Epoch 92/100
# 166/166 [==============================] - ETA: 0s - loss: 1.3295 - sparse_top_k_categorical_accuracy: 0.8883 - acc: 0.6220
# Epoch 92: ReduceLROnPlateau reducing learning rate to 2.8604481485672295e-05.
# 166/166 [==============================] - 21s 124ms/step - loss: 1.3295 - sparse_top_k_categorical_accuracy: 0.8883 - acc: 0.6220 - val_loss: 1.6824 - val_sparse_top_k_categorical_accuracy: 0.8277 - val_acc: 0.6093 - lr: 3.5756e-05
# Epoch 93/100
# 166/166 [==============================] - 21s 126ms/step - loss: 1.3260 - sparse_top_k_categorical_accuracy: 0.8880 - acc: 0.6264 - val_loss: 1.6821 - val_sparse_top_k_categorical_accuracy: 0.8283 - val_acc: 0.6097 - lr: 2.8604e-05
# Epoch 94/100
# 166/166 [==============================] - ETA: 0s - loss: 1.3125 - sparse_top_k_categorical_accuracy: 0.8889 - acc: 0.6277
# Epoch 94: ReduceLROnPlateau reducing learning rate to 2.2883585188537836e-05.
# 166/166 [==============================] - 21s 124ms/step - loss: 1.3125 - sparse_top_k_categorical_accuracy: 0.8889 - acc: 0.6277 - val_loss: 1.6818 - val_sparse_top_k_categorical_accuracy: 0.8269 - val_acc: 0.6105 - lr: 2.8604e-05
# Epoch 95/100
# 166/166 [==============================] - 20s 122ms/step - loss: 1.3125 - sparse_top_k_categorical_accuracy: 0.8900 - acc: 0.6283 - val_loss: 1.6802 - val_sparse_top_k_categorical_accuracy: 0.8278 - val_acc: 0.6105 - lr: 2.2884e-05
# Epoch 96/100
# 166/166 [==============================] - ETA: 0s - loss: 1.3122 - sparse_top_k_categorical_accuracy: 0.8897 - acc: 0.6270
# Epoch 96: ReduceLROnPlateau reducing learning rate to 1.830686815083027e-05.
# 166/166 [==============================] - 21s 124ms/step - loss: 1.3122 - sparse_top_k_categorical_accuracy: 0.8897 - acc: 0.6270 - val_loss: 1.6810 - val_sparse_top_k_categorical_accuracy: 0.8271 - val_acc: 0.6111 - lr: 2.2884e-05
# Epoch 97/100
# 166/166 [==============================] - 21s 126ms/step - loss: 1.3146 - sparse_top_k_categorical_accuracy: 0.8887 - acc: 0.6279 - val_loss: 1.6811 - val_sparse_top_k_categorical_accuracy: 0.8277 - val_acc: 0.6109 - lr: 1.8307e-05
# Epoch 98/100
# 166/166 [==============================] - 21s 125ms/step - loss: 1.3071 - sparse_top_k_categorical_accuracy: 0.8903 - acc: 0.6295 - val_loss: 1.6792 - val_sparse_top_k_categorical_accuracy: 0.8283 - val_acc: 0.6122 - lr: 1.8307e-05
# Epoch 99/100
# 166/166 [==============================] - 20s 123ms/step - loss: 1.3096 - sparse_top_k_categorical_accuracy: 0.8906 - acc: 0.6287 - val_loss: 1.6793 - val_sparse_top_k_categorical_accuracy: 0.8278 - val_acc: 0.6121 - lr: 1.8307e-05
# Epoch 100/100
# 166/166 [==============================] - ETA: 0s - loss: 1.3025 - sparse_top_k_categorical_accuracy: 0.8908 - acc: 0.6301
# Epoch 100: ReduceLROnPlateau reducing learning rate to 1.4645494229625912e-05.
# 166/166 [==============================] - 21s 125ms/step - loss: 1.3025 - sparse_top_k_categorical_accuracy: 0.8908 - acc: 0.6301 - val_loss: 1.6816 - val_sparse_top_k_categorical_accuracy: 0.8281 - val_acc: 0.6115 - lr: 1.8307e-05

# %%
model1.save('/kaggle/working/Gru_model.h5')
